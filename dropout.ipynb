# %% [markdown]
# <a href="https://colab.research.google.com/github/ubuntumel/AI_Colab_DeepLearning/blob/main/dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://colab.research.google.com/drive/1Dpj1g-D9RKYQN7j26tRxnyL57o26ElqS?usp=sharing
#
# Author: Meliton Rojas
#
# ![droput.png](data:image/png;base64,...)

# %%
import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from keras.optimizers import SGD

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
(x_train, y_train), (x_valid, y_valid) = mnist.load_data()

# %%
x_train = x_train.reshape(60000, 784).astype('float32')
x_valid = x_valid.reshape(10000, 784).astype('float32')

# %%
x_train /= 255
x_valid /= 255

# %%
n_classes = 10
y_train = keras.utils.to_categorical(y_train, n_classes)
y_valid = keras.utils.to_categorical(y_valid, n_classes)

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8027 - loss: 0.6577 - val_accuracy: 0.9493 - val_loss: 0.1656
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9556 - loss: 0.1488 - val_accuracy: 0.9623 - val_loss: 0.1218
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9690 - loss: 0.1012 - val_accuracy: 0.9641 - val_loss: 0.1133
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9762 - loss: 0.0795 - val_accuracy: 0.9681 - val_loss: 0.1048
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9787 - loss: 0.0668 - val_accuracy: 0.9713 - val_loss: 0.0949
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9841 - loss: 0.0520 - val_accuracy: 0.9709 - val_loss: 0.0963
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9844 - loss: 0.0472 - val_accuracy: 0.9743 - val_loss: 0.0916
# Epoch 8/20
# ...

# %%
history = model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_valid, y_valid))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss/Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9946 - loss: 0.0159 - val_accuracy: 0.9748 - val_loss: 0.1126
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9934 - loss: 0.0183 - val_accuracy: 0.9751 - val_loss: 0.1063
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9948 - loss: 0.0145 - val_accuracy: 0.9764 - val_loss: 0.1114
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9951 - loss: 0.0149 - val_accuracy: 0.9771 - val_loss: 0.1011
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9959 - loss: 0.0132 - val_accuracy: 0.9755 - val_loss: 0.1071
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9957 - loss: 0.0132 - val_accuracy: 0.9751 - val_loss: 0.1104
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9946 - loss: 0.0150 - val_accuracy: 0.9762 - val_loss: 0.1128
# Epoch 8/20
# ...

# %%
#print(history.history.keys())
#pd.DataFrame(history.history).plot(figsize=(8, 5))
#plt.show()

# %%
def build_model(num_hidden_layers=2, activation='relu',
                units=64, use_batchnorm=True,
                dropout_rate=0.1, dropout_after_last_hidden=True):
    model = Sequential()

    # first hidden layer
    model.add(Dense(units, activation=activation, input_shape=(784,)))
    if use_batchnorm:
        model.add(BatchNormalization())

    # remaining hidden layers
    for _ in range(num_hidden_layers - 1):
        model.add(Dense(units, activation=activation))
        if use_batchnorm:
            model.add(BatchNormalization())

    if dropout_after_last_hidden and dropout_rate and dropout_rate > 0:
        model.add(Dropout(dropout_rate))

    # output layer
    model.add(Dense(10, activation='softmax'))
    return model

# %%
results = []

configs = [
    {"hidden_layers": 3, "activation": "relu", "lr": 0.1, "dropout": 0.1},
    {"hidden_layers": 3, "activation": "relu", "lr": 0.1, "dropout": 0.2},
    {"hidden_layers": 3, "activation": "relu", "lr": 0.1, "dropout": 0.3},
    {"hidden_layers": 3, "activation": "relu", "lr": 0.1, "dropout": 0.4},
    {"hidden_layers": 3, "activation": "relu", "lr": 0.1, "dropout": 0.5},
]

for cfg in configs:
    print("\nRunning:", cfg)

    model = build_model(
    num_hidden_layers=cfg["hidden_layers"],
    activation=cfg["activation"],
    dropout_rate=cfg["dropout"],
    use_batchnorm=True
)

    model.compile(
        loss="categorical_crossentropy",
        optimizer=SGD(learning_rate=cfg["lr"]),
        metrics=["accuracy"],
    )

    history = model.fit(
        x_train, y_train,
        batch_size=128,
        epochs=20,
        verbose=0,
        validation_data=(x_valid, y_valid),
    )

    accuracy = float(np.max(history.history["val_accuracy"]))

    results.append({
    "#Hidden layer": cfg["hidden_layers"],
    "Activation Function": cfg["activation"],
    "Learning Rate": cfg["lr"],
    "Dropout": cfg["dropout"],
    "Accuracy": round(accuracy * 100, 2)
})

df = pd.DataFrame(results)

df["Dropout"] = df["Dropout"].map(lambda x: f"{x:.1f}")

df
# Out:
# Running: {'hidden_layers': 3, 'activation': 'relu', 'lr': 0.1, 'dropout': 0.1}
#
# Running: {'hidden_layers': 3, 'activation': 'relu', 'lr': 0.1, 'dropout': 0.2}
#
# Running: {'hidden_layers': 3, 'activation': 'relu', 'lr': 0.1, 'dropout': 0.3}
#
# Running: {'hidden_layers': 3, 'activation': 'relu', 'lr': 0.1, 'dropout': 0.4}
#
# Running: {'hidden_layers': 3, 'activation': 'relu', 'lr': 0.1, 'dropout': 0.5}
#    #Hidden layer Activation Function  Learning Rate Dropout  Accuracy
# 0              3                relu            0.1     0.1     97.78
# 1              3                relu            0.1     0.2     97.82
# 2              3                relu            0.1     0.3     97.73
# 3              3                relu            0.1     0.4     97.66
# 4              3                relu            0.1     0.5     97.68
